# %% [markdown]
# # 01. 4.8 Grouping Data & Aggregating variables

# %% [markdown]
# # Import Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
# Set path
path = r'/Users/mohammedRusso/Documents/DATA_ANALYST_COURSE/DATA_Immersion_Submissions/Assingment 4/01-2025 Instacart Basket Analysis'

# %%
# import data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'prepared Data', 'ords_prods_merge_dervd.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 17)

# %%
#creating a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
# 5                    15.0         196                  1          1   both
# 6                    15.0       10258                  2          0   both
# 7                    15.0       12427                  3          1   both
# 8                    15.0       13176                  4          0   both
# 9                    15.0       26088                  5          1   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5                                     Soda        77              7     9.0
# 6                               Pistachios       117             19     3.0
# 7                      Original Beef Jerky        23             19     4.4
# 8                   Bag of Organic Bananas        24              4    10.3
# 9               Aged White Cheddar Popcorn        23             19     4.7
#
#   match      busiest_days busiest_perdiod_of_day
# 0  both      Regular Days         Average orders
# 1  both      Regular Days         Average orders
# 2  both      Regular Days         Average orders
# 3  both      Regular Days         Average orders
# 4  both      Regular Days         Average orders
# 5  both  Two slowest Days         Average orders
# 6  both  Two slowest Days         Average orders
# 7  both  Two slowest Days         Average orders
# 8  both  Two slowest Days         Average orders
# 9  both  Two slowest Days         Average orders

# %%
grouped = df.groupby('product_name')

# %%
aggregated = grouped['user_id'].sum()
print(aggregated)
# Out:
# product_name
# #2 Coffee Filters                                                   92386
# #4 Natural Brown Coffee Filters                                      5373
# & Go! Hazelnut Spread + Pretzel Sticks                             104869
# 0 Calorie Acai Raspberry Water Beverage                             10521
# 0 Calorie Fuji Apple Pear Water Beverage                             7860
#                                                                     ...
# with Xylitol Minty Sweet Twist 18 Sticks Sugar Free Gum              2253
# with Xylitol Original Flavor 18 Sticks Sugar Free Gum              159469
# with Xylitol Unwrapped Original Flavor 50 Sticks Sugar Free Gum     12188
# with Xylitol Unwrapped Spearmint 50 Sticks Sugar Free Gum           21035
# with Xylitol Watermelon Twist 18 Sticks Sugar Free Gum               4535
# Name: user_id, Length: 31240, dtype: int64

# %%
df.tail()
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 999995   2789027     6474             2                   3
# 999996   2789027     6474             2                   3
# 999997   2789027     6474             2                   3
# 999998   2789027     6474             2                   3
# 999999   2789027     6474             2                   3
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 999995                  8                    30.0        3020
# 999996                  8                    30.0       35823
# 999997                  8                    30.0       27681
# 999998                  8                    30.0        2091
# 999999                  8                    30.0       44199
#
#         add_to_cart_order  reordered _merge  \
# 999995                  7          0   both
# 999996                  8          0   both
# 999997                  9          0   both
# 999998                 10          0   both
# 999999                 11          0   both
#
#                                              product_name  aisle_id  \
# 999995                 Broccoli & Apple Stage 2 Baby Food        92
# 999996  Complete Foaming Antibacterial Hand Soap Varie...       127
# 999997               Lower Sugar Instant Oatmeal  Variety       130
# 999998                   Almond Nut & Rice Cracker Snacks        78
# 999999        Toll House Mini Chocolate Chip Cookie Dough       105
#
#         department_id  prices match      busiest_days busiest_perdiod_of_day
# 999995             18    12.9  both  Two slowest Days         Average orders
# 999996             11     7.3  both  Two slowest Days         Average orders
# 999997             14     3.5  both  Two slowest Days         Average orders
# 999998             19     6.8  both  Two slowest Days         Average orders
# 999999             13     2.9  both  Two slowest Days         Average orders

# %%
#Performing a Single Aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
#Performing Multiple Aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
#Aggregating Data with transform()
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# 1                      NaN       14084                  2          0   both
# 2                      NaN       12427                  3          0   both
# 3                      NaN       26088                  4          0   both
# 4                      NaN       26405                  5          0   both
# 5                     15.0         196                  1          1   both
# 6                     15.0       10258                  2          0   both
# 7                     15.0       12427                  3          1   both
# 8                     15.0       13176                  4          0   both
# 9                     15.0       26088                  5          1   both
# 10                    15.0       13032                  6          0   both
# 11                    21.0         196                  1          1   both
# 12                    21.0       12427                  2          1   both
# 13                    21.0       10258                  3          1   both
# 14                    21.0       25133                  4          0   both
#
#                                product_name  aisle_id  department_id  prices  \
# 0                                      Soda        77              7     9.0
# 1   Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                       Original Beef Jerky        23             19     4.4
# 3                Aged White Cheddar Popcorn        23             19     4.7
# 4          XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5                                      Soda        77              7     9.0
# 6                                Pistachios       117             19     3.0
# 7                       Original Beef Jerky        23             19     4.4
# 8                    Bag of Organic Bananas        24              4    10.3
# 9                Aged White Cheddar Popcorn        23             19     4.7
# 10                    Cinnamon Toast Crunch       121             14     4.0
# 11                                     Soda        77              7     9.0
# 12                      Original Beef Jerky        23             19     4.4
# 13                               Pistachios       117             19     3.0
# 14                    Organic String Cheese        21             16     8.6
#
#    match      busiest_days busiest_perdiod_of_day  max_order  loyalty_flag
# 0   both      Regular Days         Average orders         10  New customer
# 1   both      Regular Days         Average orders         10  New customer
# 2   both      Regular Days         Average orders         10  New customer
# 3   both      Regular Days         Average orders         10  New customer
# 4   both      Regular Days         Average orders         10  New customer
# 5   both  Two slowest Days         Average orders         10  New customer
# 6   both  Two slowest Days         Average orders         10  New customer
# 7   both  Two slowest Days         Average orders         10  New customer
# 8   both  Two slowest Days         Average orders         10  New customer
# 9   both  Two slowest Days         Average orders         10  New customer
# 10  both  Two slowest Days         Average orders         10  New customer
# 11  both  Two slowest Days            Most orders         10  New customer
# 12  both  Two slowest Days            Most orders         10  New customer
# 13  both  Two slowest Days            Most orders         10  New customer
# 14  both  Two slowest Days            Most orders         10  New customer

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                      NaN       14084                  2          0
# 2                      NaN       12427                  3          0
# 3                      NaN       26088                  4          0
# 4                      NaN       26405                  5          0
# ..                     ...         ...                ...        ...
# 95                     8.0       21150                 13          0
# 96                     8.0       47144                  1          0
# 97                     8.0        5322                  2          0
# 98                     8.0       17224                  3          0
# 99                     8.0       38656                  4          0
#
#                                          product_name  aisle_id  \
# 0                                                Soda        77
# 1             Organic Unsweetened Vanilla Almond Milk        91
# 2                                 Original Beef Jerky        23
# 3                          Aged White Cheddar Popcorn        23
# 4                    XL Pick-A-Size Paper Towel Rolls        54
# ..                                                ...       ...
# 95                            Fire Grilled Steak Bowl        38
# 96     Unsweetened Original Almond Breeze Almond Milk        91
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98                   Oats & Honey Gluten Free Granola         3
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices    price_range_loc   busiest_day      busiest_days  \
# 0               7     9.0  Mid-range product  Regular busy      Regular Days
# 1              16    12.5  Mid-range product  Regular busy      Regular Days
# 2              19     4.4  Low-range product  Regular busy      Regular Days
# 3              19     4.7  Low-range product  Regular busy      Regular Days
# 4              17     1.0  Low-range product  Regular busy      Regular Days
# ..            ...     ...                ...           ...               ...
# 95              1     5.9  Mid-range product  Regular busy      Regular Days
# 96             16    14.0  Mid-range product  Regular busy  Two slowest Days
# 97             19     2.9  Low-range product  Regular busy  Two slowest Days
# 98             19     1.6  Low-range product  Regular busy  Two slowest Days
# 99             19     3.4  Low-range product  Regular busy  Two slowest Days
#
#    busiest_perdiod_of_day  max_order
# 0          Average orders         10
# 1          Average orders         10
# 2          Average orders         10
# 3          Average orders         10
# 4          Average orders         10
# ..                    ...        ...
# 95            Most orders         14
# 96            Most orders         14
# 97            Most orders         14
# 98            Most orders         14
# 99            Most orders         14
#
# [100 rows x 18 columns]

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                      NaN       14084                  2          0
# 2                      NaN       12427                  3          0
# 3                      NaN       26088                  4          0
# 4                      NaN       26405                  5          0
# ..                     ...         ...                ...        ...
# 95                     8.0       21150                 13          0
# 96                     8.0       47144                  1          0
# 97                     8.0        5322                  2          0
# 98                     8.0       17224                  3          0
# 99                     8.0       38656                  4          0
#
#                                          product_name  aisle_id  \
# 0                                                Soda        77
# 1             Organic Unsweetened Vanilla Almond Milk        91
# 2                                 Original Beef Jerky        23
# 3                          Aged White Cheddar Popcorn        23
# 4                    XL Pick-A-Size Paper Towel Rolls        54
# ..                                                ...       ...
# 95                            Fire Grilled Steak Bowl        38
# 96     Unsweetened Original Almond Breeze Almond Milk        91
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98                   Oats & Honey Gluten Free Granola         3
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices    price_range_loc   busiest_day      busiest_days  \
# 0               7     9.0  Mid-range product  Regular busy      Regular Days
# 1              16    12.5  Mid-range product  Regular busy      Regular Days
# 2              19     4.4  Low-range product  Regular busy      Regular Days
# 3              19     4.7  Low-range product  Regular busy      Regular Days
# 4              17     1.0  Low-range product  Regular busy      Regular Days
# ..            ...     ...                ...           ...               ...
# 95              1     5.9  Mid-range product  Regular busy      Regular Days
# 96             16    14.0  Mid-range product  Regular busy  Two slowest Days
# 97             19     2.9  Low-range product  Regular busy  Two slowest Days
# 98             19     1.6  Low-range product  Regular busy  Two slowest Days
# 99             19     3.4  Low-range product  Regular busy  Two slowest Days
#
#    busiest_perdiod_of_day  max_order
# 0          Average orders         10
# 1          Average orders         10
# 2          Average orders         10
# 3          Average orders         10
# 4          Average orders         10
# ..                    ...        ...
# 95            Most orders         14
# 96            Most orders         14
# 97            Most orders         14
# 98            Most orders         14
# 99            Most orders         14
#
# [100 rows x 18 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %% [markdown]
# # 4.8 Task

# %%
# Question 2. aggregated mean of the “order_number” column grouped by “department_id” for entire dataset
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']}).reset_index()
# Out:
#    department_id order_number
#                          mean
# 0              1    15.457838
# 1              2    17.277920
# 2              3    17.170395
# 3              4    17.811403
# 4              5    15.215751
# 5              6    16.439806
# 6              7    17.225802
# 7              8    15.340650
# 8              9    15.895474
# 9             10    20.197148
# 10            11    16.170638
# 11            12    15.887671
# 12            13    16.583536
# 13            14    16.773669
# 14            15    16.165037
# 15            16    17.665606
# 16            17    15.694469
# 17            18    19.310397
# 18            19    17.177343
# 19            20    16.473447
# 20            21    22.902379

# %% [markdown]
# #### Question 3. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.
#
# ##### The subet dataframe has a higher average of order number compared to the whole dataframe but there aren't any extreme differences.

# %% [markdown]
# #### Q4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#Aggregating Data with transform(). creating new column 'max_order'
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform("max")

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Examining Value Counts on 'loyalty_flag'
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# checking updated dataframe 
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(5)
# Out:
#    user_id  loyalty_flag  order_number
# 0   202279  New customer             3
# 1   202279  New customer             3
# 2   202279  New customer             3
# 3   202279  New customer             3
# 4   202279  New customer             3

# %% [markdown]
# #### Q5. Analyzing spending habits of identifed customers

# %%
#Aggregating Data with transform()
ords_prods_merge.groupby(['loyalty_flag']).agg({'prices': ['min', 'max', 'mean']})
# Out:
#                  prices
#                     min      max       mean
# loyalty_flag
# Loyal customer      1.0  99999.0  10.386336
# New customer        1.0  99999.0  13.294670
# Regular customer    1.0  99999.0  12.495717

# %% [markdown]
# ##### Loyal customers on average purchase lower priced items compared to new and regular customers

# %% [markdown]
# #### Q6. Create a spending flag for each user based on the average price across all their orders

# %%
#Aggregating Data with transform(). creating new column 'average_price'
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform("mean")

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'prices', 'avg_price']].head(5)
# Out:
#    user_id  loyalty_flag  prices  avg_price
# 0   202279  New customer    11.3   8.618889
# 1   202279  New customer    13.4   8.618889
# 2   202279  New customer     3.6   8.618889
# 3   202279  New customer     8.4   8.618889
# 4   202279  New customer    13.7   8.618889

# %%
#If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”
ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Examining Value Counts on 'Spending_flag'
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
# Checking Releavent Columns
ords_prods_merge[['user_id', 'avg_price', 'spending_flag']].head(15)
# Out:
#     user_id  avg_price spending_flag
# 0    202279   8.618889   Low spender
# 1    202279   8.618889   Low spender
# 2    202279   8.618889   Low spender
# 3    202279   8.618889   Low spender
# 4    202279   8.618889   Low spender
# 5    202279   8.618889   Low spender
# 6    202279   8.618889   Low spender
# 7    202279   8.618889   Low spender
# 8    202279   8.618889   Low spender
# 9    205970   8.681734   Low spender
# 10   205970   8.681734   Low spender
# 11   205970   8.681734   Low spender
# 12   205970   8.681734   Low spender
# 13   205970   8.681734   Low spender
# 14   205970   8.681734   Low spender

# %% [markdown]
# #### Q7. Create an order frequency flag that marks the regularity of a user’s ordering behavior

# %%
ords_prods_merge.head(1)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         2   202279             3                   5                  9
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     8.0     33120.0                1.0        1.0
#
#          product_name  aisle_id  department_id  prices _merge  max_order  \
# 0  Organic Egg Whites        86             16    11.3   both          8
#
#    loyalty_flag  avg_price spending_flag
# 0  New customer   8.618889   Low spender

# %%
#Aggregating Data with transform(). creating new column 'median_days_order'
ords_prods_merge['median_days_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform("median")

# %%
#checking column created
ords_prods_merge[['user_id', 'median_days_order']].head(1)
# Out:
#    user_id  median_days_order
# 0   202279               24.0

# %%
#If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
ords_prods_merge.loc[ords_prods_merge['median_days_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
#If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
ords_prods_merge.loc[(ords_prods_merge['median_days_order'] > 10) &(ords_prods_merge['median_days_order'] <= 20) , 'frequency_flag'] = 'Regular customer'

# %%
#If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”
ords_prods_merge.loc[ords_prods_merge['median_days_order'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Examining Value Counts on 'Spending_flag'
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
# Checking Releavent Columns
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_order', 'frequency_flag']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_order         frequency_flag
# 0    202279                     8.0               24.0  Non-frequent customer
# 1    202279                     8.0               24.0  Non-frequent customer
# 2    202279                     8.0               24.0  Non-frequent customer
# 3    202279                     8.0               24.0  Non-frequent customer
# 4    202279                     8.0               24.0  Non-frequent customer
# 5    202279                     8.0               24.0  Non-frequent customer
# 6    202279                     8.0               24.0  Non-frequent customer
# 7    202279                     8.0               24.0  Non-frequent customer
# 8    202279                     8.0               24.0  Non-frequent customer
# 9    205970                    12.0                8.0      Frequent customer
# 10   205970                    12.0                8.0      Frequent customer
# 11   205970                    12.0                8.0      Frequent customer
# 12   205970                    12.0                8.0      Frequent customer
# 13   205970                    12.0                8.0      Frequent customer
# 14   205970                    12.0                8.0      Frequent customer

# %% [markdown]
# #### Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived_grouped.pkl'))

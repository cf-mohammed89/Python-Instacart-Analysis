# %% [markdown]
# # 01. Importing Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as nm
import os

# %% [markdown]
# # 02. Importing Data

# %%
# Setting path
path = r'/Users/mohammedRusso/Documents/DATA_ANALYST_COURSE/DATA_Immersion_Submissions/Assingment 4/01-2025 Instacart Basket Analysis'

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False) 
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head(15)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0      1868044         1   112108             4                   4
# 1      3355525         2   202279             3                   5
# 2      3355525         2   202279             3                   5
# 3      3355525         2   202279             3                   5
# 4      3355525         2   202279             3                   5
# 5      3355525         2   202279             3                   5
# 6      3355525         2   202279             3                   5
# 7      3355525         2   202279             3                   5
# 8      3355525         2   202279             3                   5
# 9      3355525         2   202279             3                   5
# 10     3417191         3   205970            16                   5
# 11     3417191         3   205970            16                   5
# 12     3417191         3   205970            16                   5
# ...

# %%
#df_merged_large(['_merge'], how = 'outer').value_counts()
df_merged_large = pd.merge(df_ords, df_ords_prior, how='outer', on='order_id', indicator = True)

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only       206209
# right_only           0
# Name: count, dtype: int64

# %%
#export to csv
df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %%
#Export to pkl
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_merged_large
# Out:
#           Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            1868044         1   112108             4                   4
# 1            3355525         2   202279             3                   5
# 2            3355525         2   202279             3                   5
# 3            3355525         2   202279             3                   5
# 4            3355525         2   202279             3                   5
# ...              ...       ...      ...           ...                 ...
# 32640693      419472   3421083    25247            24                   2
# 32640694      419472   3421083    25247            24                   2
# 32640695      419472   3421083    25247            24                   2
# 32640696      419472   3421083    25247            24                   2
# 32640697      419472   3421083    25247            24                   2
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...
